# %%
import tweepy
from tweepy import OAuthHandler

consumer_key = '__________________________'
consumer_secret = '_____________________'
access_token = '________________________________'
access_secret = '____________________________________'

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)

# %%
from tweepy import Stream
from tweepy.streaming import StreamListener
 
class MyListener(StreamListener):
 
    def on_data(self, data):
        try:
            with open('ArtificialIntelligenceTweets.json', 'a') as f:
                f.write(data)
                return True
        except BaseException as e:
            print("Error on_data: %s" % str(e))
        return True
 
    def on_error(self, status):
        print(status)
        return True
    
twitter_stream = Stream(auth, MyListener())
twitter_stream.filter(track=['ArtificialIntelligence'])

# %%
import json  
with open('ArtificialIntelligenceTweets.json','r') as json_file:
         for line in json_file:
            tweet = json.loads(line)
            print tweet["text"]
# Out:
# RT @evankirstel: #AI for everyone: Democratizing intelligence across companies of all sizes. https://t.co/Zd4zj57ipP @AccentureTech…
# RT @Ronald_vanLoon: 30 Emerging Technologies You Need to Know About | #Artificialintelligence #IoT #RT https://t.co/8GqrC33mJI https://t.co…
# RT @jose_garde: "Mind Versus Machine: Human Insight in the Age of #Automation" https://t.co/8zvr4xhV6V #BigData #artificialintelligence
# https://t.co/VowRCTIVR5 #Womeninscience #womenintech #ArtificialIntelligence #elonMusk #NikolaTesla
# https://t.co/h1xPMrYpnq #Womeninscience #womenintech #ArtificialIntelligence #elonMusk #NikolaTesla
# The latest The Artificial intelligence IOT Insurance Reinsurance Daily! https://t.co/aCPz5XmRse #artificialintelligence
# RT @Findout_Ltd: What is #DataScience?: https://t.co/V66l4t4QPy   #abdsc #BigData #MachineLearning #ai #artificialintelligence https://t.co…
# RT @Findout_Ltd: What is #DataScience?: https://t.co/V66l4t4QPy   #abdsc #BigData #MachineLearning #ai #artificialintelligence https://t.co…
# RT @jose_garde: "Mind Versus Machine: Human Insight in the Age of #Automation" https://t.co/8zvr4xhV6V #BigData #artificialintelligence

# %%
import json  
with open('ArtificialIntelligenceTweets.json', 'r') as f:
    line = f.readline() 
    tweet = json.loads(line) 
    print(json.dumps(tweet, indent=4))
# Out:
# {
#     "contributors": null,
#     "truncated": false,
#     "text": "RT @evankirstel: #AI for everyone: Democratizing intelligence across companies of all sizes.\u00a0https://t.co/Zd4zj57ipP @AccentureTech\u2026 ",
#     "is_quote_status": false,
#     "in_reply_to_status_id": null,
#     "id": 859115088481071105,
#     "favorite_count": 0,
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "retweeted": false,
#     "coordinates": null,
#     "timestamp_ms": "1493663973337",
#     "entities": {
#         "user_mentions": [
#             {
#                 "id": 35203319,
#                 "indices": [
#                     3,
#                     15
#                 ],
#                 "id_str": "35203319",
#                 "screen_name": "evankirstel",
#                 "name": "Evan Kirstel"
#             },
#             {
#                 "id": 2423931254,
#                 "indices": [
#                     117,
#                     131
#                 ],
#                 "id_str": "2423931254",
#                 "screen_name": "AccentureTech",
#                 "name": "Accenture Technology"
#             }
#         ],
#         "symbols": [],
#         "hashtags": [
#             {
#                 "indices": [
#                     17,
#                     20
#                 ],
#                 "text": "AI"
#             }
#         ],
#         "urls": [
#             {
#                 "url": "https://t.co/Zd4zj57ipP",
#                 "indices": [
#                     93,
#                     116
#                 ],
#                 "expanded_url": "http://accntu.re/2qlhZGy",
#                 "display_url": "accntu.re/2qlhZGy"
#             },
#             {
#                 "url": "",
#                 "indices": [
#                     133,
#                     133
#                 ],
#                 "expanded_url": null
#             }
#         ]
#     },
#     "in_reply_to_screen_name": null,
#     "id_str": "859115088481071105",
#     "retweet_count": 0,
#     "in_reply_to_user_id": null,
#     "favorited": false,
#     "retweeted_status": {
#         "contributors": null,
#         "truncated": true,
#         "text": "#AI for everyone: Democratizing intelligence across companies of all sizes.\u00a0https://t.co/Zd4zj57ipP @AccentureTech\u2026 https://t.co/chFGbBzoeI",
#         "is_quote_status": false,
#         "in_reply_to_status_id": null,
#         "id": 859068435552141314,
#         "favorite_count": 4,
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "retweeted": false,
#         "coordinates": null,
#         "entities": {
#             "user_mentions": [
#                 {
#                     "id": 2423931254,
#                     "indices": [
#                         100,
#                         114
#                     ],
#                     "id_str": "2423931254",
#                     "screen_name": "AccentureTech",
#                     "name": "Accenture Technology"
#                 }
#             ],
#             "symbols": [],
#             "hashtags": [
#                 {
#                     "indices": [
#                         0,
#                         3
#                     ],
#                     "text": "AI"
#                 }
#             ],
#             "urls": [
#                 {
#                     "url": "https://t.co/Zd4zj57ipP",
#                     "indices": [
#                         76,
#                         99
#                     ],
#                     "expanded_url": "http://accntu.re/2qlhZGy",
#                     "display_url": "accntu.re/2qlhZGy"
#                 },
#                 {
#                     "url": "https://t.co/chFGbBzoeI",
#                     "indices": [
#                         116,
#                         139
#                     ],
#                     "expanded_url": "https://twitter.com/i/web/status/859068435552141314",
#                     "display_url": "twitter.com/i/web/status/8\u2026"
#                 }
#             ]
#         },
#         "in_reply_to_screen_name": null,
#         "id_str": "859068435552141314",
#         "display_text_range": [
#             0,
#             140
#         ],
#         "retweet_count": 13,
#         "in_reply_to_user_id": null,
#         "favorited": false,
#         "user": {
#             "follow_request_sent": null,
#             "profile_use_background_image": true,
#             "default_profile_image": false,
#             "id": 35203319,
#             "verified": false,
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/851789549760114688/O00UQbT6_normal.jpg",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "followers_count": 116836,
#             "profile_sidebar_border_color": "C0DEED",
#             "id_str": "35203319",
#             "profile_background_color": "C0DEED",
#             "listed_count": 12776,
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "utc_offset": -14400,
#             "statuses_count": 490694,
#             "description": "#Solopreneur #Influencer #ThoughtLeader Helping #B2B clients w #SocialMedia in #Enterprise\u25aa\ufe0f #IoT\u25aa\ufe0f #Telecom\u25aa\ufe0f #Cloud \u25aa\ufe0f #Mobile LinkedIn: https://goo.gl/xJteF6",
#             "friends_count": 96862,
#             "location": "Boston, MA",
#             "profile_link_color": "1DA1F2",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/851789549760114688/O00UQbT6_normal.jpg",
#             "following": null,
#             "geo_enabled": true,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/35203319/1473528821",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "name": "Evan Kirstel",
#             "lang": "en",
#             "profile_background_tile": false,
#             "favourites_count": 421828,
#             "screen_name": "evankirstel",
#             "notifications": null,
#             "url": "http://evankirstel.com",
#             "created_at": "Sat Apr 25 12:45:16 +0000 2009",
#             "contributors_enabled": false,
#             "time_zone": "Eastern Time (US & Canada)",
#             "protected": false,
#             "default_profile": true,
#             "is_translator": false
#         },
#         "geo": null,
#         "in_reply_to_user_id_str": null,
#         "possibly_sensitive": false,
#         "lang": "en",
#         "extended_tweet": {
#             "display_text_range": [
#                 0,
#                 138
#             ],
#             "entities": {
#                 "user_mentions": [
#                     {
#                         "id": 2423931254,
#                         "indices": [
#                             100,
#                             114
#                         ],
#                         "id_str": "2423931254",
#                         "screen_name": "AccentureTech",
#                         "name": "Accenture Technology"
#                     }
#                 ],
#                 "symbols": [],
#                 "hashtags": [
#                     {
#                         "indices": [
#                             0,
#                             3
#                         ],
#                         "text": "AI"
#                     },
#                     {
#                         "indices": [
#                             115,
#                             138
#                         ],
#                         "text": "ArtificialIntelligence"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "url": "https://t.co/Zd4zj57ipP",
#                         "indices": [
#                             76,
#                             99
#                         ],
#                         "expanded_url": "http://accntu.re/2qlhZGy",
#                         "display_url": "accntu.re/2qlhZGy"
#                     }
#                 ],
#                 "media": [
#                     {
#                         "expanded_url": "https://twitter.com/evankirstel/status/859068435552141314/photo/1",
#                         "display_url": "pic.twitter.com/qOdNbyRtJt",
#                         "url": "https://t.co/qOdNbyRtJt",
#                         "media_url_https": "https://pbs.twimg.com/media/C-wGLzZW0AA43vi.jpg",
#                         "id_str": "859068428765810688",
#                         "sizes": {
#                             "large": {
#                                 "h": 335,
#                                 "resize": "fit",
#                                 "w": 600
#                             },
#                             "small": {
#                                 "h": 335,
#                                 "resize": "fit",
#                                 "w": 600
#                             },
#                             "medium": {
#                                 "h": 335,
#                                 "resize": "fit",
#                                 "w": 600
#                             },
#                             "thumb": {
#                                 "h": 150,
#                                 "resize": "crop",
#                                 "w": 150
#                             }
#                         },
#                         "indices": [
#                             139,
#                             162
#                         ],
#                         "type": "photo",
#                         "id": 859068428765810688,
#                         "media_url": "http://pbs.twimg.com/media/C-wGLzZW0AA43vi.jpg"
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "expanded_url": "https://twitter.com/evankirstel/status/859068435552141314/photo/1",
#                         "display_url": "pic.twitter.com/qOdNbyRtJt",
#                         "url": "https://t.co/qOdNbyRtJt",
#                         "media_url_https": "https://pbs.twimg.com/media/C-wGLzZW0AA43vi.jpg",
#                         "id_str": "859068428765810688",
#                         "sizes": {
#                             "large": {
#                                 "h": 335,
#                                 "resize": "fit",
#                                 "w": 600
#                             },
#                             "small": {
#                                 "h": 335,
#                                 "resize": "fit",
#                                 "w": 600
#                             },
#                             "medium": {
#                                 "h": 335,
#                                 "resize": "fit",
#                                 "w": 600
#                             },
#                             "thumb": {
#                                 "h": 150,
#                                 "resize": "crop",
#                                 "w": 150
#                             }
#                         },
#                         "indices": [
#                             139,
#                             162
#                         ],
#                         "type": "photo",
#                         "id": 859068428765810688,
#                         "media_url": "http://pbs.twimg.com/media/C-wGLzZW0AA43vi.jpg"
#                     }
#                 ]
#             },
#             "full_text": "#AI for everyone: Democratizing intelligence across companies of all sizes.\u00a0https://t.co/Zd4zj57ipP @AccentureTech #ArtificialIntelligence https://t.co/qOdNbyRtJt"
#         },
#         "created_at": "Mon May 01 15:34:10 +0000 2017",
#         "filter_level": "low",
#         "in_reply_to_status_id_str": null,
#         "place": null
#     },
#     "user": {
#         "follow_request_sent": null,
#         "profile_use_background_image": true,
#         "default_profile_image": false,
#         "id": 2269957598,
#         "verified": false,
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/661600701978537984/c_HfNfrF_normal.jpg",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "followers_count": 99462,
#         "profile_sidebar_border_color": "C0DEED",
#         "id_str": "2269957598",
#         "profile_background_color": "C0DEED",
#         "listed_count": 764,
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "utc_offset": 7200,
#         "statuses_count": 38856,
#         "description": "EXPand Amplifies Twitter Communication to widen your Marketing Funnel - Lead by Top50 Social Media Influencer @RichSimmondsZA in association with @UwinIwinINT",
#         "friends_count": 101116,
#         "location": "Worldwide",
#         "profile_link_color": "1DA1F2",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/661600701978537984/c_HfNfrF_normal.jpg",
#         "following": null,
#         "geo_enabled": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/2269957598/1414247899",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "name": "EXPand Amplification",
#         "lang": "en",
#         "profile_background_tile": false,
#         "favourites_count": 53,
#         "screen_name": "EXPandAMP",
#         "notifications": null,
#         "url": "http://www.richsimmondsza.com",
#         "created_at": "Tue Dec 31 06:16:57 +0000 2013",
#         "contributors_enabled": false,
#         "time_zone": "Pretoria",
#         "protected": false,
#         "default_profile": true,
#         "is_translator": false
#     },
#     "geo": null,
#     "in_reply_to_user_id_str": null,
#     "possibly_sensitive": false,
#     "lang": "en",
#     "created_at": "Mon May 01 18:39:33 +0000 2017",
#     "filter_level": "low",
#     "in_reply_to_status_id_str": null,
#     "place": null
# }

# %%
import re
 
emoticons_str = r"""
    (?:
        [:=;] # Eyes
        [oO\-]? # Nose (optional)
        [D\)\]\(\]/\\OpP] # Mouth
    )"""
 
regex_str = [
    emoticons_str,
    r'<[^>]+>', # HTML tags
    r'(?:@[\w_]+)', # @-mentions
    r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)", # hash-tags
    r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', # URLs
 
    r'(?:(?:\d+,?)+(?:\.?\d+)?)', # numbers
    r"(?:[a-z][a-z'\-_]+[a-z])", # words with - and '
    r'(?:[\w_]+)', # other words
    r'(?:\S)' # anything else
]
    
tokens_re = re.compile(r'('+'|'.join(regex_str)+')', re.VERBOSE | re.IGNORECASE)
emoticon_re = re.compile(r'^'+emoticons_str+'$', re.VERBOSE | re.IGNORECASE)
 
def tokenize(s):
    return tokens_re.findall(s)
 
def preprocess(s, lowercase=False):
    tokens = tokenize(s)
    if lowercase:
        tokens = [token if emoticon_re.search(token) else token.lower() for token in tokens]
    return tokens

# %%
with open('ArtificialIntelligenceTweets.json', 'r') as f:
    for line in f:
        tweet = json.loads(line)
        tokens = preprocess(tweet['text'])
        print(tokens)
# Out:
# [u'RT', u'@evankirstel', u':', u'#AI', u'for', u'everyone', u':', u'Democratizing', u'intelligence', u'across', u'companies', u'of', u'all', u'sizes', u'.', u'\xa0', u'https://t.co/Zd4zj57ipP', u'@AccentureTech', u'\u2026']
# [u'RT', u'@Ronald_vanLoon', u':', u'30', u'Emerging', u'Technologies', u'You', u'Need', u'to', u'Know', u'About', u'|', u'#Artificialintelligence', u'#IoT', u'#RT', u'https://t.co/8GqrC33mJI', u'https://t.co', u'\u2026']
# [u'RT', u'@jose_garde', u':', u'"', u'Mind', u'Versus', u'Machine', u':', u'Human', u'Insight', u'in', u'the', u'Age', u'of', u'#Automation', u'"', u'https://t.co/8zvr4xhV6V', u'#BigData', u'#artificialintelligence']
# [u'https://t.co/VowRCTIVR5', u'#Womeninscience', u'#womenintech', u'#ArtificialIntelligence', u'#elonMusk', u'#NikolaTesla']
# [u'https://t.co/h1xPMrYpnq', u'#Womeninscience', u'#womenintech', u'#ArtificialIntelligence', u'#elonMusk', u'#NikolaTesla']
# [u'The', u'latest', u'The', u'Artificial', u'intelligence', u'IOT', u'Insurance', u'Reinsurance', u'Daily', u'!', u'https://t.co/aCPz5XmRse', u'#artificialintelligence']
# [u'RT', u'@Findout_Ltd', u':', u'What', u'is', u'#DataScience', u'?', u':', u'https://t.co/V66l4t4QPy', u'#abdsc', u'#BigData', u'#MachineLearning', u'#ai', u'#artificialintelligence', u'https://t.co', u'\u2026']
# [u'RT', u'@Findout_Ltd', u':', u'What', u'is', u'#DataScience', u'?', u':', u'https://t.co/V66l4t4QPy', u'#abdsc', u'#BigData', u'#MachineLearning', u'#ai', u'#artificialintelligence', u'https://t.co', u'\u2026']
# [u'RT', u'@jose_garde', u':', u'"', u'Mind', u'Versus', u'Machine', u':', u'Human', u'Insight', u'in', u'the', u'Age', u'of', u'#Automation', u'"', u'https://t.co/8zvr4xhV6V', u'#BigData', u'#artificialintelligence']

# %%
import nltk
from nltk.corpus import stopwords
nltk.download("stopwords") # download the stopword corpus on our computer
import string
 
punctuation = list(string.punctuation)
stop = stopwords.words('english') + punctuation + ['rt', 'via', 'RT']
# Out:
# [nltk_data] Downloading package stopwords to /Users/Toni/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import operator 
import json
from collections import Counter

fname = 'ArtificialIntelligenceTweets.json'
with open(fname, 'r') as f:
    count_all = Counter()
    for line in f:
        tweet = json.loads(line)
        # Create a list with all the terms
        terms_stop = [term for term in preprocess(tweet['text']) if term not in stop] 
        # Update the counter
        count_all.update(terms_stop)
    print(count_all.most_common(5))
# Out:
# [(u'#artificialintelligence', 5), (u'\u2026', 4), (u'#BigData', 4), (u'https://t.co', 3), (u'intelligence', 2)]
